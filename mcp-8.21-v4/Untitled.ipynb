# %%
cd /root/cursor-mcp-plan8.18-1.19/backend
mvn -U -DskipTests clean compile
mvn -U -DskipTests spring-boot:run

# %%
# 进入项目目录
cd /root/cursor-mcp-plan1/backend/src/main/java/com/yumanus/amap/

# 删除Jupyter临时文件
rm -rf .ipynb_checkpoints/

# %%
cd /root/cursor-mcp-plan8.18-1.19/web
npm i
npm run dev -- --host 0.0.0.0 --port 5173

# %%
npm run dev -- --host 0.0.0.0 --port 5173
cd /root/cursor-mcp-plan8.18-1.19/web
npm i
npm run dev -- --host 0.0.0.0 --port 5173

# %%
hostname -I | awk '{print $1}'
# 或
ip -4 addr show eth0 | grep -oP '(?<=inet\s)\d+(\.\d+){3}'

# %%
ssh -NT -p 52914 -L 5175:172.17.0.9:5175 -L 8080:172.17.0.2:8080 root@region-9.autodl.pro

# %%
密码：TUtu9116

# %%
http://localhost:5175

后端：http://localhost:8080

记得保持 ssh -NT -p 52914 -L 5175:172.17.0.2:5175 -L 8080:172.17.0.2:8080 root@region-9.autodl.pro 这个窗口不断开。
