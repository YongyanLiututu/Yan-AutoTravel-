# %%
cd /root/cursor-mcp-plan1/backend
mvn -U -DskipTests clean compile
mvn -U -DskipTests spring-boot:run

# %%
cd /root/cursor-mcp-plan1/web
npm i

# %%
npm run dev -- --host 0.0.0.0 --port 5173

# %%
ssh -NT -p 52914 -L 5175:172.17.0.2:5175 -L 8080:172.17.0.2:8080 root@region-9.autodl.pro

# %%
密码：TUtu9116

# %%
http://localhost:5175

后端：http://localhost:8080

记得保持 ssh -NT -p 52914 -L 5175:172.17.0.2:5175 -L 8080:172.17.0.2:8080 root@region-9.autodl.pro 这个窗口不断开。
